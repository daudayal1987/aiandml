# %%
# !pip install mistralai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 9.4 MB/s eta 0:00:00
# ...

# %%
import os
import mistralai

# %%
MISTRAL_KEY_API = "REPLACE-YOUR-API-KEY-HERE"
client = mistralai.Mistral(api_key=MISTRAL_KEY_API)

# %%
all_models = client.models.list()
all_models
# Out:
# ModelList(object='list', data=[BaseModelCard(id='mistral-medium-2505', capabilities=ModelCapabilities(completion_chat=True, completion_fim=False, function_calling=True, fine_tuning=False, vision=True, classification=False), object='model', created=1753193636, owned_by='mistralai', name='mistral-medium-2505', description='Official mistral-medium-2505 Mistral AI model', max_context_length=131072, aliases=['mistral-medium-latest', 'mistral-medium'], deprecation=None, deprecation_replacement_model=None, default_model_temperature=0.3, TYPE='base'), BaseModelCard(id='mistral-medium-latest', capabilities=ModelCapabilities(completion_chat=True, completion_fim=False, function_calling=True, fine_tuning=False, vision=True, classification=False), object='model', created=1753193636, owned_by='mistralai', name='mistral-medium-2505', description='Official mistral-medium-2505 Mistral AI model', max_context_length=131072, aliases=['mistral-medium-2505', 'mistral-medium'], deprecation=None, deprecatio
# ...

# %%
for model in all_models.data:
  print(model.id, '==>', model.capabilities, end="\n")
# Out:
# mistral-medium-2505 ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=False vision=True classification=False
# mistral-medium-latest ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=False vision=True classification=False
# mistral-medium ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=False vision=True classification=False
# ministral-3b-2410 ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=True vision=False classification=False
# ministral-3b-latest ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=True vision=False classification=False
# ministral-8b-2410 ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=False vision=False classification=False
# ministral-8b-latest ==> completion_chat=True completion_fim=False function_calling=True fine_tuning=False vision=False classification=False
# ...
